# %% [markdown]
# <a href="https://colab.research.google.com/github/Alaina47/project2ict/blob/main/project2ict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NumPy** **Problems**
#
# ---

# %% [markdown]
# 1.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/content/1774404110.csv')

mpg = df['mpg'].to_numpy()

mean_mpg = np.mean(mpg)
median_mpg = np.median(mpg)
std_mpg = np.std(mpg)

print(f"Mean MPG: {mean_mpg:.2f}")
print(f"Median MPG: {median_mpg:.2f}")
print(f"Standard Deviation: {std_mpg:.2f}")
# Out:
# Mean MPG: 23.51
# Median MPG: 23.00
# Standard Deviation: 7.81

# %%
count_mpg_gt_25 = np.sum(mpg > 25)
print(f"Number of cars with MPG greater than 25: {count_mpg_gt_25}")
# Out:
# Number of cars with MPG greater than 25: 158

# %% [markdown]
# 2

# %%
car_names_gt_6_cylinders = cars_gt_6_cylinders['car name'].to_list()
print("Cars with more than 6 cylinders:")
for name in car_names_gt_6_cylinders:
    print(name)
# Out:
# Cars with more than 6 cylinders:
# chevrolet chevelle malibu
# buick skylark 320
# plymouth satellite
# amc rebel sst
# ford torino
# ford galaxie 500
# chevrolet impala
# plymouth fury iii
# pontiac catalina
# amc ambassador dpl
# dodge challenger se
# plymouth 'cuda 340
# chevrolet monte carlo
# buick estate wagon (sw)
# ford f250
# chevy c20
# dodge d200
# hi 1200d
# chevrolet impala
# pontiac catalina brougham
# ford galaxie 500
# plymouth fury iii
# dodge monaco (sw)
# ford country squire (sw)
# pontiac safari (sw)
# chevrolet impala
# pontiac catalina
# plymouth fury iii
# ford galaxie 500
# amc ambassador sst
# mercury marquis
# buick lesabre custom
# oldsmobile delta 88 royale
# chrysler newport royal
# amc matador (sw)
# chevrolet chevelle concours (sw)
# ford gran torino (sw)
# plymouth satellite custom (sw)
# buick century 350
# amc matador
# chevrolet malibu
# ford gran torino
# dodge coronet custom
# mercury marquis brougham
# chevrolet caprice classic
# ford ltd
# ...

# %% [markdown]
# 3

# %%
horsepower = df['horsepower']


horsepower_numeric = pd.to_numeric(horsepower, errors='coerce')


mean_horsepower = horsepower_numeric.mean()
horsepower_filled = horsepower_numeric.fillna(mean_horsepower)


increased_horsepower_array = (horsepower_filled * 1.1).to_numpy()

# Convert 'weight' column to numeric, coercing errors
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')

print("Original Horsepower (first 5 values):")
print(horsepower.head().to_numpy())
print("\nIncreased Horsepower Array (first 5 values):")
print(increased_horsepower_array[:5])
print("\nWeight (first 5 values) after conversion:")
print(df['weight'].head().to_numpy())
# Out:
# Original Horsepower (first 5 values):
# ['130' '165' '150' '150' '140']
#
# Increased Horsepower Array (first 5 values):
# [143.  181.5 165.  165.  154. ]
#
# Weight (first 5 values) after conversion:
# [3504 3693 3436 3433 3449]

# %% [markdown]
# 4

# %%
europe_cars = df[df['origin'] == 2]
average_displacement_europe = np.mean(europe_cars['displacement'])

print(f"Average displacement of cars with origin 2 (Europe): {average_displacement_europe:.2f}")
# Out:
# Average displacement of cars with origin 2 (Europe): 109.14

# %% [markdown]
# 5

# %%
import numpy as np
import pandas as pd

# Load the DataFrame from the CSV file
df = pd.read_csv('/content/1774404110.csv')

unique_cylinders = df['cylinders'].unique()
mean_mpg_by_cylinders = {}

for c in unique_cylinders:
    # Filter mpg for current cylinder count and convert to numpy array
    cyl_mpg = df[df['cylinders'] == c]['mpg'].to_numpy()
    mean_mpg_by_cylinders[c] = np.mean(cyl_mpg)

print("Mean MPG by number of cylinders:")
for cyl, mean_mpg_val in mean_mpg_by_cylinders.items():
    print(f"Cylinders: {cyl}, Mean MPG: {mean_mpg_val:.2f}")
# Out:
# Mean MPG by number of cylinders:
# Cylinders: 8, Mean MPG: 14.96
# Cylinders: 4, Mean MPG: 29.29
# Cylinders: 6, Mean MPG: 19.99
# Cylinders: 3, Mean MPG: 20.55
# Cylinders: 5, Mean MPG: 27.37

# %% [markdown]
# **Pandas Problems**
#
# ---

# %% [markdown]
# 1

# %%
import pandas as pd
df = pd.read_csv('/content/1774404110.csv')
print("First 10 rows of the DataFrame:")
display(df.head(10))
print(f"\nTotal number of rows: {df.shape[0]}")
print(f"Total number of columns: {df.shape[1]}")
print("\nSummary statistics for numerical columns:")
display(df.describe())
# Out:
# First 10 rows of the DataFrame:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# 2

# %%
filtered_cars = df[(df['model year'] == 75) & (df['weight'] < 3000)]
result_df = filtered_cars[['car name', 'weight', 'mpg']]
display(result_df)
# Out:
#               car name  weight   mpg
# 167     toyota corolla    2171  29.0
# 168         ford pinto    2639  23.0
# 169        amc gremlin    2914  20.0
# 170      pontiac astro    2592  23.0
# 171      toyota corona    2702  24.0
# 172  volkswagen dasher    2223  25.0
# 173         datsun 710    2545  24.0
# 174         ford pinto    2984  18.0
# 175  volkswagen rabbit    1937  29.0
# 177         audi 100ls    2694  23.0
# 178        peugeot 504    2957  23.0
# 179        volvo 244dl    2945  22.0
# 180          saab 99le    2671  25.0
# 181   honda civic cvcc    1795  33.0

# %% [markdown]
# 3

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# mpg                      0
# cylinders                0
# displacement             0
# horsepower               0
# weight                   0
# acceleration             0
# model year               0
# origin                   0
# car name                 0
# power_to_weight_ratio    0
# dtype: int64

# %% [markdown]
# 4

# %%
df['power_to_weight_ratio'] = horsepower_filled / df['weight']
display(df.head())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name  power_to_weight_ratio
# 0       1  chevrolet chevelle malibu               0.037100
# 1       1          buick skylark 320               0.044679
# 2       1         plymouth satellite               0.043655
# 3       1              amc rebel sst               0.043694
# 4       1                ford torino               0.040591

# %% [markdown]
# 5

# %%
mean_mpg_by_origin = df.groupby('origin')['mpg'].mean()
print(mean_mpg_by_origin)
# Out:
# Mean MPG by Origin:
# origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: mpg, dtype: float64

# %% [markdown]
# 6

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
mean_horsepower = df['horsepower'].mean()
df['horsepower'] = df['horsepower'].fillna(mean_horsepower)

summary_df = df.groupby('model year')[['mpg', 'weight', 'horsepower']].mean()
display(summary_df)
# Out:
#                   mpg       weight  horsepower
# model year
# 70          17.689655  3372.793103  147.827586
# 71          21.250000  2995.428571  106.945335
# 72          18.714286  3237.714286  120.178571
# 73          17.100000  3419.025000  130.475000
# 74          22.703704  2877.925926   94.609977
# 75          20.266667  3176.800000  101.066667
# 76          21.573529  3078.735294  101.117647
# 77          23.375000  2997.357143  105.071429
# 78          24.061111  2861.805556   99.694444
# 79          25.093103  3055.344828  101.206897
# 80          33.696552  2436.655172   79.342716
# 81          30.334483  2522.931034   81.843772
# 82          31.709677  2453.548387   82.208690

# %% [markdown]
# 7

# %%
import pandas as pd
df = pd.read_csv('/content/1774404110.csv')
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
mean_horsepower = df['horsepower'].mean()
df['horsepower'] = df['horsepower'].fillna(mean_horsepower)
high_mpg_cars_df = df[df['mpg'] > 30][['mpg', 'cylinders', 'horsepower', 'weight']]
high_mpg_cars_df.to_csv('high_mpg_cars.csv', index=False)
print("Saved 'high_mpg_cars.csv' successfully.")
display(high_mpg_cars_df.head())
# Out:
# Saved 'high_mpg_cars.csv' successfully.
#       mpg  cylinders  horsepower  weight
# 53   31.0          4        65.0    1773
# 54   35.0          4        69.0    1613
# 129  31.0          4        67.0    1950
# 131  32.0          4        65.0    1836
# 144  31.0          4        52.0    1649
